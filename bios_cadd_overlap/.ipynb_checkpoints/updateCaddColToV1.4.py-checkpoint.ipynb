# %%
# !/usr/bin/env python3
# -*- coding: utf-8 -*-
################################################################################
#   File Name  : updateCaddColToV1.4
##  Author     : zhzhang
### E-mail     : zhzhang2015@sina.com
### Created on : Sun 12 Nov 2018 10:14:46 PM CET
##  Version    : v0.0.1
#   License    : MIT
################################################################################

# Load basic modules
import os
import sys                                                                      
import time
import logging


# Start a timer.
ct = time.clock()  # Time counting starts


# Create stream handler of logging
## Logging info formatter
FORMATTER = '%(asctime)s <%(name)s> %(levelname)s: %(message)s'
formatter = logging.Formatter(FORMATTER, '%Y-%m-%d,%H:%M:%S')

## Set up main logging stream and formatter
ch = logging.StreamHandler()
ch.setLevel(logging.INFO)
ch.setFormatter(formatter)


# Set up logging
lg = logging.getLogger()
lg.setLevel(logging.INFO)         # default logging level INFO
lg.addHandler(ch)
lg.info("=== Start ... ===")

# Load necessay modules
lg.info("Load necessay modules...")
# e.g import pandas as pd


# Arrange working dirs
lg.info('Arrange working dirs...')
hmDir = '/home/umcg-zzhang'
pjDir = os.path.join(hmDir, 'Documents', 'projects', 'ASEpredictor')
pjOpDir = os.path.join(pjDir, 'outputs')
# pjIpDir = os.path.join(pjDir, 'inputs')
# pjSpDir = os.path.join(pjDir, 'scripts')
# pjMcDir = os.path.join(pjDir, 'misc')


# Arrange input and output files
lg.info('Arrange input and output files...')

debug = True
if debug:
    tk = '_head2000'
else:
    tk = ''
bcDir = os.path.join(pjOpDir, 'biosCadd')
bcIpFile = os.path.join(bcDir, 'biosCadd' + tk + '.tsv')

bgoDir = os.path.join(pjOpDir, 'biosGavinOverlapCov10')
bgoIpFile = os.path.join(bgoDir, 'biosGavinOlCv10AntUfltCst' + tk + '.tsv')

uccOpDir = os.path.join(pjOpDir, 'biosGavinOlCv10AntUfltCstCadd1.4')
uccOpFile = os.path.join(uccOpDir, 'biosGavinOlCv10AntUfltCstCadd1.4' + tk + '.tsv')


import pandas as pd
    
bcd = pd.read_table(bcIpFile, header=1)
bgod = pd.read_table(bgoIpFile, header=1)

bcd['index'] = bcd['#Chrom'] + bcd['Pos'] + bcd['Ref'] +

print(bcd)


    
# Finished the logging & time counting ends
lg.info("=== Done  ... ===\nTime elapsed: %0.2sf" %(time.clock()-ct) )
# Out:
# /home/umcg-zzhang/Tools/Anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:20: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
# 2018-11-12,10:53:11 <root> INFO: === Start ... ===
# 2018-11-12,10:53:11 <root> INFO: === Start ... ===
# 2018-11-12,10:53:11 <root> INFO: === Start ... ===
# 2018-11-12,10:53:11 <root> INFO: === Start ... ===
# 2018-11-12,10:53:11 <root> INFO: === Start ... ===
# 2018-11-12,10:53:11 <root> INFO: Load necessay modules...
# 2018-11-12,10:53:11 <root> INFO: Load necessay modules...
# 2018-11-12,10:53:11 <root> INFO: Load necessay modules...
# 2018-11-12,10:53:11 <root> INFO: Load necessay modules...
# 2018-11-12,10:53:11 <root> INFO: Load necessay modules...
# 2018-11-12,10:53:11 <root> INFO: Arrange working dirs...
# 2018-11-12,10:53:11 <root> INFO: Arrange working dirs...
# 2018-11-12,10:53:11 <root> INFO: Arrange working dirs...
# ...

# %%
# Update the file description of the README.md file.
def udRm(shortName, fullName):
    pass
